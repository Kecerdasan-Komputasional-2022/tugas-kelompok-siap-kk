jpg'
# '/tmp/cats_and_dogs_filtered/train/cats/cat.951.jpg' -> '/content/drive/My Drive/Colab Notebooks/Dataset CNN/cats_and_dogs_filtered/train/cats/cat.951.jpg'
# '/tmp/cats_and_dogs_filtered/train/cats/cat.950.jpg' -> '/content/drive/My Drive/Colab Notebooks/Dataset CNN/cats_and_dogs_filtered/train/cats/cat.950.jpg'
# '/tmp/cats_and_dogs_filtered/train/cats/cat.949.jpg' -> '/content/drive/My Drive/Colab Notebooks/Dataset CNN/cats_and_dogs_filtered/train/cats/cat.949.jpg'
# '/tmp/cats_and_dogs_filtered/train/cats/cat.948.jpg' -> '/content/drive/My Drive/Colab Notebooks/Dataset CNN/cats_and_dogs_filtered/train/cats/cat.948.jpg'
# '/tmp/cats_and_dogs_filtered/train/cats/cat.947.jpg' -> '/content/drive/My Drive/Colab Notebooks/Dataset CNN/cats_and_dogs_filtered/train/cats/cat.947.jpg'
# '/tmp/cats_and_dogs_filtered/train/cats/cat.946.jpg' -> '/content/drive/My Drive/Colab Notebooks/Dataset CNN/cats_and_dogs_filtered/train/cats/cat.946.jpg'
# '/tmp/cats_and_dogs_filtered/train/cats/cat.945.jpg' -> '/content/drive/My Drive/Colab Notebooks/Dataset CNN/cats_and_dogs_filtered/train/cats/cat.945.jpg'
# '/tmp/cats_and_dogs_filtered/train/cats/cat.944.jpg' -> '/content/drive/My Drive/Colab Notebooks/Dataset CNN/cats_and_dogs_filtered/train/cats/cat.944.jpg'
# '/tmp/cats_and_dogs_filtered/train/cats/cat.943.jpg' -> '/content/drive/My Drive/Colab Notebooks/Dataset CNN/cats_and_dogs_filtered/train/cats/cat.943.jpg'
# '/tmp/cats_and_dogs_filtered/train/cats/cat.942.jpg' -> '/content/drive/My Drive/Colab Notebooks/Dataset CNN/cats_and_dogs_filtered/train/cats/cat.942.jpg'
# '/tmp/cats_and_dogs_filtered/train/cats/cat.941.jpg' -> '/content/drive/My Drive/Colab Notebooks/Dataset CNN/cats_and_dogs_filtered/train/cats/cat.941.jpg'
# '/tmp/cats_and_dogs_filtered/train/cats/cat.940.jpg' -> '/content/drive/My Drive/Colab Notebooks/Dataset CNN/cats_and_dogs_filtered/train/cats/cat.940.jpg'
# '/tmp/cats_and_dogs_filtered/train/cats/cat.939.jpg' -> '/content/drive/My Drive/Colab Notebooks/Dataset CNN/cats_and_dogs_filtered/train/cats/cat.939.jpg'
# '/tmp/cats_and_dogs_filtered/train/cats/cat.938.jpg' -> '/content/drive/My Drive/Colab Notebooks/Dataset CNN/cats_and_dogs_filtered/train/cats/cat.938.jpg'
# '/tmp/cats_and_dogs_filtered/train/cats/cat.937.jpg' -> '/content/drive/My Drive/Colab Notebooks/Dataset CNN/cats_and_dogs_filtered/train/cats/cat.937.jpg'
# '/tmp/cats_and_dogs_filtered/train/cats/cat.936.jpg' -> '/content/drive/My Drive/Colab Notebooks/Dataset CNN/cats_and_dogs_filtered/train/cats/cat.936.jpg'
# '/tmp/cats_and_dogs_filtered/train/cats/cat.935.jpg' -> '/content/drive/My Drive/Colab Notebooks/Dataset CNN/cats_and_dogs_filtered/train/cats/cat.935.jpg'
# '/tmp/cats_and_dogs_filtered/train/cats/cat.934.jpg' -> '/content/drive/My Drive/Colab Notebooks/Dataset CNN/cats_and_dogs_filtered/train/cats/cat.934.jpg'
# '/tmp/cats_and_dogs_filtered/train/cats/cat.933.jpg' -> '/content/drive/My Drive/Colab Notebooks/Dataset CNN/cats_and_dogs_filtered/train/cats/cat.933.jpg'
# '/tmp/cats_and_dogs_filtered/train/cats/cat.932.jpg' -> '/content/drive/My Drive/Colab Notebooks/Dataset CNN/cats_and_dogs_filtered/train/cats/cat.932.jpg'
# '/tmp/cats_and_dogs_filtered/train/cats/cat.931.jpg' -> '/content/drive/My Drive/Colab Notebooks/Dataset CNN/cats_and_dogs_filtered/train/cats/cat.931.jpg'
# '/tmp/cats_and_dogs_filtered/train/cats/cat.930.jpg' -> '/content/drive/My Drive/Colab Notebooks/Dataset CNN/cats_and_dogs_filtered/train/cats/cat.930.jpg'
# '/tmp/cats_and_dogs_filtered/train/cats/cat.929.jpg' -> '/content/drive/My Drive/Colab Notebooks/Dataset CNN/cats_and_dogs_filtered/train/cats/cat.929.jpg'
# '/tmp/cats_and_dogs_filtered/train/cats/cat.928.jpg' -> '/content/drive/My Drive/Colab Notebooks/Dataset CNN/cats_and_dogs_filtered/train/cats/cat.928.jpg'
# '/tmp/cats_and_dogs_filtered/train/cats/cat.927.jpg' -> '/content/drive/My Drive/Colab Notebooks/Dataset CNN/cats_and_dogs_filtered/train/cats/cat.927.jpg'
# '/tmp/cats_and_dogs_filtered/train/cats/cat.926.jpg' -> '/content/drive/My Drive/Colab Notebooks/Dataset CNN/cats_and_dogs_filtered/train/cats/cat.926.jpg'
# '/tmp/cats_and_dogs_filtered/train/cats/cat.925.jpg' -> '/content/drive/My Drive/Colab Notebooks/Dataset CNN/cats_and_dogs_filtered/train/cats/cat.925.jpg'
# '/tmp/cats_and_dogs_filtered/train/cats/cat.924.jpg' -> '/content/drive/My Drive/Colab Notebooks/Dataset CNN/cats_and_dogs_filtered/train/cats/cat.924.jpg'
# '/tmp/cats_and_dogs_filtered/train/cats/cat.923.jpg' -> '/content/drive/My Drive/Colab Notebooks/Dataset CNN/cats_and_dogs_filtered/train/cats/cat.923.jpg'
# '/tmp/cats_and_dogs_filtered/train/cats/cat.922.jpg' -> '/content/drive/My Drive/Colab Notebooks/Dataset CNN/cats_and_dogs_filtered/train/cats/cat.922.jpg'
# '/tmp/cats_and_dogs_filtered/train/cats/cat.921.jpg' -> '/content/drive/My Drive/Colab Notebooks/Dataset CNN/cats_and_dogs_filtered/train/cats/cat.921.jpg'
# '/tmp/cats_and_dogs_filtered/train/cats/cat.920.jpg' -> '/content/drive/My Drive/Colab Notebooks/Dataset CNN/cats_and_dogs_filtered/train/cats/cat.920.jpg'
# '/tmp/cats_and_dogs_filtered/train/cats/cat.919.jpg' -> '/content/drive/My Drive/Colab Notebooks/Dataset CNN/cats_and_dogs_filtered/train/cats/cat.919.jpg'
# '/tmp/cats_and_dogs_filtered/train/cats/cat.918.jpg' -> '/content/drive/My Drive/Colab Notebooks/Dataset CNN/cats_and_dogs_filtered/train/cats/cat.918.jpg'
# '/tmp/cats_and_dogs_filtered/train/cats/cat.917.jpg' -> '/content/drive/My Drive/Colab Notebooks/Dataset CNN/cats_and_dogs_filtered/train/cats/cat.917.jpg'
# '/tmp/cats_and_dogs_filtered/train/cats/cat.916.jpg' -> '/content/drive/My Drive/Colab Notebooks/Dataset CNN/cats_and_dogs_filtered/train/cats/cat.916.jpg'
# '/tmp/cats_and_dogs_filtered/train/cats/cat.915.jpg' -> '/content/drive/My Drive/Colab Notebooks/Dataset CNN/cats_and_dogs_filtered/train/cats/cat.915.jpg'
# '/tmp/cats_and_dogs_filtered/train/cats/cat.914.jpg' -> '/content/drive/My Drive/Colab Notebooks/Dataset CNN/cats_and_dogs_filtered/train/cats/cat.914.jpg'
# '/tmp/cats_and_dogs_filtered/train/cats/cat.913.jpg' -> '/content/drive/My Drive/Colab Notebooks/Dataset CNN/cats_and_dogs_filtered/train/cats/cat.913.jpg'
# '/tmp/cats_and_dogs_filtered/train/cats/cat.912.jpg' -> '/content/drive/My Drive/Colab Notebooks/Dataset CNN/cats_and_dogs_filtered/train/cats/cat.912.jpg'
# '/tmp/cats_and_dogs_filtered/train/cats/cat.911.jpg' -> '/content/drive/My Drive/Colab Notebooks/Dataset CNN/cats_and_dogs_filtered/train/cats/cat.911.jpg'
# '/tmp/cats_and_dogs_filtered/train/cats/cat.910.jpg' -> '/content/drive/My Drive/Colab Notebooks/Dataset CNN/cats_and_dogs_filtered/train/cats/cat.910.jpg'
# '/tmp/cats_and_dogs_filtered/train/cats/cat.909.jpg' -> '/content/drive/My Drive/Colab Notebooks/Dataset CNN/cats_and_dogs_filtered/train/cats/cat.909.jpg'
# '/tmp/cats_and_dogs_filtered/train/cats/cat.908.jpg' -> '/content/drive/My Drive/Colab Notebooks/Dataset CNN/cats_and_dogs_filtered/train/cats/cat.908.jpg'
# '/tmp/cats_and_dogs_filtered/train/cats/cat.907.jpg' -> '/content/drive/My Drive/Colab Notebooks/Dataset CNN/cats_and_dogs_filtered/train/cats/cat.907.jpg'
# '/tmp/cats_and_dogs_filtered/train/cats/cat.906.jpg' -> '/content/drive/My Drive/Colab Notebooks/Dataset CNN/cats_and_dogs_filtered/train/cats/cat.906.jpg'
# '/tmp/cats_and_dogs_filtered/train/cats/cat.905.jpg' -> '/content/drive/My Drive/Colab Notebooks/Dataset CNN/cats_and_dogs_filtered/train/cats/cat.905.jpg'
# '/tmp/cats_and_dogs_filtered/train/cats/cat.904.jpg' -> '/content/drive/My Drive/Colab Notebooks/Dataset CNN/cats_and_dogs_filtered/train/cats/cat.904.jpg'
# '/tmp/cats_and_dogs_filtered/train/cats/cat.903.jpg' -> '/content/drive/My Drive/Colab Notebooks/Dataset CNN/cats_and_dogs_filtered/train/cats/cat.903.jpg'
# '/tmp/cats_and_dogs_filtered/train/cats/cat.902.jpg' -> '/content/drive/My Drive/Colab Notebooks/Dataset CNN/cats_and_dogs_filtered/train/cats/cat.902.jpg'
# '/tmp/cats_and_dogs_filtered/train/cats/cat.901.jpg' -> '/content/drive/My Drive/Colab Notebooks/Dataset CNN/cats_and_dogs_filtered/train/cats/cat.901.jpg'
# '/tmp/cats_and_dogs_filtered/train/cats/cat.900.jpg' -> '/content/drive/My Drive/Colab Notebooks/Dataset CNN/cats_and_dogs_filtered/train/cats/cat.900.jpg'
# '/tmp/cats_and_dogs_filtered/train/cats/cat.899.jpg' -> '/content/drive/My Drive/Colab Notebooks/Dataset CNN/cats_and_dogs_filtered/train/cats/cat.899.jpg'
# '/tmp/cats_and_dogs_filtered/train/cats/cat.898.jpg' -> '/content/drive/My Drive/Colab Notebooks/Dataset CNN/cats_and_dogs_filtered/train/cats/cat.898.jpg'
# '/tmp/cats_and_dogs_filtered/train/cats/cat.897.jpg' -> '/content/drive/My Drive/Colab Notebooks/Dataset CNN/cats_and_dogs_filtered/train/cats/cat.897.jpg'
# '/tmp/cats_and_dogs_filtered/train/cats/cat.896.jpg' -> '/content/drive/My Drive/Colab Notebooks/Dataset CNN/cats_and_dogs_filtered/train/cats/cat.896.jpg'

# %% [markdown]
# ## Set directory dari Google drive

# %%
base_dir = '/content/drive/My Drive/Colab Notebooks/Dataset CNN/cats_and_dogs_filtered'
train_dir = os.path.join(base_dir, 'train')
validation_dir = os.path.join(base_dir, 'validation')

# Directory with our training cat pictures
train_cats_dir = os.path.join(train_dir, 'cats')

# Directory with our training dog pictures
train_dogs_dir = os.path.join(train_dir, 'dogs')

# Directory with our validation cat pictures
validation_cats_dir = os.path.join(validation_dir, 'cats')

# Directory with our validation dog pictures
validation_dogs_dir = os.path.join(validation_dir, 'dogs')

# %% [markdown]
# ## Melihat isi dataset

# %%
train_cat_fnames = os.listdir(train_cats_dir)
print(train_cat_fnames[:10])

train_dog_fnames = os.listdir(train_dogs_dir)
train_dog_fnames.sort()
print(train_dog_fnames[:10])
# Out:
# ['cat.127.jpg', 'cat.126.jpg', 'cat.125.jpg', 'cat.124.jpg', 'cat.123.jpg', 'cat.122.jpg', 'cat.121.jpg', 'cat.120.jpg', 'cat.119.jpg', 'cat.118.jpg']
# ['dog.0.jpg', 'dog.1.jpg', 'dog.10.jpg', 'dog.100.jpg', 'dog.101.jpg', 'dog.102.jpg', 'dog.103.jpg', 'dog.104.jpg', 'dog.105.jpg', 'dog.106.jpg']

# %%
print('total training cat images:', len(os.listdir(train_cats_dir)))
print('total training dog images:', len(os.listdir(train_dogs_dir)))
print('total validation cat images:', len(os.listdir(validation_cats_dir)))
print('total validation dog images:', len(os.listdir(validation_dogs_dir)))
# Out:
# total training cat images: 1000
# total training dog images: 1000
# total validation cat images: 500
# total validation dog images: 500

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Parameters for our graph; we'll output images in a 4x4 configuration
nrows = 4
ncols = 4

# Index for iterating over images
pic_index = 0

# %%
# Set up matplotlib fig, and size it to fit 4x4 pics
fig = plt.gcf()
fig.set_size_inches(ncols * 4, nrows * 4)

pic_index += 8
next_cat_pix = [os.path.join(train_cats_dir, fname) 
                for fname in train_cat_fnames[pic_index-8:pic_index]]
next_dog_pix = [os.path.join(train_dogs_dir, fname) 
                for fname in train_dog_fnames[pic_index-8:pic_index]]

for i, img_path in enumerate(next_cat_pix+next_dog_pix):
  # Set up subplot; subplot indices start at 1
  sp = plt.subplot(nrows, ncols, i + 1)
  sp.axis('Off') # Don't show axes (or gridlines)

  img = mpimg.imread(img_path)
  plt.imshow(img)

plt.show()

# %% [markdown]
# ## Import library tensorflow

# %%
from tensorflow.keras import layers
from tensorflow.keras import Model

# %% [markdown]
# ## Setting arsitektur CNN (Konvolusi)

# %%
# Our input feature map is 150x150x3: 150x150 for the image pixels, and 3 for
# the three color channels: R, G, and B
img_input = layers.Input(shape=(150, 150, 3))

# First convolution extracts 16 filters that are 3x3
# Convolution is followed by max-pooling layer with a 2x2 window
x = layers.Conv2D(16, 3, activation='relu')(img_input)
x = layers.MaxPooling2D(2)(x)

# Second convolution extracts 32 filters that are 3x3
# Convolution is followed by max-pooling layer with a 2x2 window
x = layers.Conv2D(32, 3, activation='relu')(x)
x = layers.MaxPooling2D(2)(x)

# Third convolution extracts 64 filters that are 3x3
# Convolution is followed by max-pooling layer with a 2x2 window
x = layers.Conv2D(64, 3, activation='relu')(x)
x = layers.MaxPooling2D(2)(x)

# %% [markdown]
# ## Setting arsitektur CNN (Fully Connected)

# %%
# Flatten feature map to a 1-dim tensor so we can add fully connected layers
x = layers.Flatten()(x)

# Create a fully connected layer with ReLU activation and 512 hidden units
x = layers.Dense(512, activation='relu')(x)

# Create output layer with a single node and sigmoid activation
output = layers.Dense(1, activation='sigmoid')(x)

# Create model:
# input = input feature map
# output = input feature map + stacked convolution/maxpooling layers + fully 
# connected layer + sigmoid output layer
model = Model(img_input, output)

# %% [markdown]
# ## Compile CNN

# %%
from tensorflow.keras.optimizers import RMSprop

# Karena terdapat 2 kelas, maka loss compile menggunakan 'binary_crossentropy'
# Jika terdapat banyak kelas, maka loss comppile menggunakan 'categorical_crossentropy'
model.compile(loss='binary_crossentropy',
              optimizer=RMSprop(lr=0.001),
              metrics=['acc'])
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizers/optimizer_v2/rmsprop.py:135: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(RMSprop, self).__init__(name, **kwargs)

# %% [markdown]
# ## Setting preparasi dataset

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# All images will be rescaled by 1./255
train_datagen = ImageDataGenerator(rescale=1./255)
val_datagen = ImageDataGenerator(rescale=1./255)

# Flow training images in batches of 20 using train_datagen generator
train_generator = train_datagen.flow_from_directory(
        train_dir,  # This is the source directory for training images
        target_size=(150, 150),  # All images will be resized to 150x150
        batch_size=20,
        # Since we use binary_crossentropy loss, we need binary labels
        class_mode='binary')

# Flow validation images in batches of 20 using val_datagen generator
validation_generator = val_datagen.flow_from_directory(
        validation_dir,
        target_size=(150, 150),
        batch_size=20,
        class_mode='binary')
# Out:
# Found 2000 images belonging to 2 classes.
# Found 1000 images belonging to 2 classes.

# %% [markdown]
# ## Proses training, bisa membutuhkan waktu beberapa menit

# %%
history = model.fit_generator(
      train_generator,
      steps_per_epoch=100,  # 2000 images = batch_size * steps
      epochs=15,
      validation_data=validation_generator,
      validation_steps=50,  # 1000 images = batch_size * steps
      verbose=2)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   import sys
# Epoch 1/15
# 100/100 - 22s - loss: 0.7273 - acc: 0.5360 - val_loss: 0.6540 - val_acc: 0.6250 - 22s/epoch - 219ms/step
# Epoch 2/15
# 100/100 - 12s - loss: 0.6677 - acc: 0.6335 - val_loss: 0.6034 - val_acc: 0.7180 - 12s/epoch - 119ms/step
# Epoch 3/15
# 100/100 - 12s - loss: 0.5532 - acc: 0.7195 - val_loss: 0.5865 - val_acc: 0.6980 - 12s/epoch - 118ms/step
# Epoch 4/15
# 100/100 - 13s - loss: 0.4790 - acc: 0.7620 - val_loss: 0.6038 - val_acc: 0.6980 - 13s/epoch - 128ms/step
# Epoch 5/15
# 100/100 - 12s - loss: 0.3936 - acc: 0.8155 - val_loss: 0.7559 - val_acc: 0.6710 - 12s/epoch - 118ms/step
# Epoch 6/15
# 100/100 - 12s - loss: 0.3224 - acc: 0.8610 - val_loss: 0.6684 - val_acc: 0.6810 - 12s/epoch - 119ms/step
# Epoch 7/15
# 100/100 - 12s - loss: 0.2343 - acc: 0.9045 - val_loss: 0.8435 - val_acc: 0.6840 - 12s/epoch - 117ms/step
# Epoch 8/15
# 100/100 - 12s - loss: 0.1494 - acc: 0.9375 - val_loss: 0.9461 - val_acc: 0.6830 - 12s/epoch - 117ms/step
# Epoch 9/15
# 100/100 - 14s - loss: 0.1031 - acc: 0.9630 - val_loss: 1.1724 - val_acc: 0.6850 - 14s/epoch - 140ms/step
# Epoch 10/15
# 100/100 - 12s - loss: 0.0822 - acc: 0.9710 - val_loss: 1.2409 - val_acc: 0.6760 - 12s/epoch - 117ms/step
# Epoch 11/15
# 100/100 - 12s - loss: 0.0550 - acc: 0.9800 - val_loss: 1.5699 - val_acc: 0.7030 - 12s/epoch - 118ms/step
# Epoch 12/15
# 100/100 - 12s - loss: 0.0573 - acc: 0.9865 - val_loss: 1.6704 - val_acc: 0.6900 - 12s/epoch - 118ms/step
# Epoch 13/15
# 100/100 - 12s - loss: 0.0510 - acc: 0.9870 - val_loss: 2.0127 - val_acc: 0.6910 - 12s/epoch - 124ms/step
# Epoch 14/15
# 100/100 - 12s - loss: 0.0208 - acc: 0.9910 - val_loss: 2.1115 - val_acc: 0.6930 - 12s/epoch - 118ms/step
# Epoch 15/15
# 100/100 - 12s - loss: 0.0374 - acc: 0.9895 - val_loss: 2.1742 - val_acc: 0.6700 - 12s/epoch - 120ms/step

# %% [markdown]
# ## Menampilkan hasil tiap langkah

# %%
import numpy as np
import random
from tensorflow.keras.preprocessing.image import img_to_array, load_img

# Let's define a new Model that will take an image as input, and will output
# intermediate representations for all layers in the previous model after
# the first.
successive_outputs = [layer.output for layer in model.layers[1:]]
visualization_model = Model(img_input, successive_outputs)

# Let's prepare a random input image of a cat or dog from the training set.
cat_img_files = [os.path.join(train_cats_dir, f) for f in train_cat_fnames]
dog_img_files = [os.path.join(train_dogs_dir, f) for f in train_dog_fnames]
img_path = random.choice(cat_img_files + dog_img_files)

img = load_img(img_path, target_size=(150, 150))  # this is a PIL image
x = img_to_array(img)  # Numpy array with shape (150, 150, 3)
x = x.reshape((1,) + x.shape)  # Numpy array with shape (1, 150, 150, 3)

# Rescale by 1/255
x /= 255

# Let's run our image through our network, thus obtaining all
# intermediate representations for this image.
successive_feature_maps = visualization_model.predict(x)

# These are the names of the layers, so can have them as part of our plot
layer_names = [layer.name for layer in model.layers]

# Now let's display our representations
for layer_name, feature_map in zip(layer_names, successive_feature_maps):
  if len(feature_map.shape) == 4:
    # Just do this for the conv / maxpool layers, not the fully-connected layers
    n_features = feature_map.shape[-1]  # number of features in feature map
    # The feature map has shape (1, size, size, n_features)
    size = feature_map.shape[1]
    # We will tile our images in this matrix
    display_grid = np.zeros((size, size * n_features))
    for i in range(n_features):
      # Postprocess the feature to make it visually palatable
      x = feature_map[0, :, :, i]
      x -= x.mean()
      x /= x.std()
      x *= 64
      x += 128
      x = np.clip(x, 0, 255).astype('uint8')
      # We'll tile each filter into this big horizontal grid
      display_grid[:, i * size : (i + 1) * size] = x
    # Display the grid
    scale = 20. / n_features
    plt.figure(figsize=(scale * n_features, scale))
    plt.title(layer_name)
    plt.grid(False)
    plt.imshow(display_grid, aspect='auto', cmap='viridis')
# Out:
# 1/1 [==============================] - 0s 185ms/step
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:43: RuntimeWarning: invalid value encountered in true_divide

# %% [markdown]
# ## Menampilkan grafik selama pelatihan

# %%
# Retrieve a list of accuracy results on training and validation data
# sets for each training epoch
acc = history.history['acc']
val_acc = history.history['val_acc']

# Retrieve a list of list results on training and validation data
# sets for each training epoch
loss = history.history['loss']
val_loss = history.history['val_loss']

# Get number of epochs
epochs = range(len(acc))

# Plot training and validation accuracy per epoch
plt.plot(epochs, acc)
plt.plot(epochs, val_acc)
plt.title('Training and validation accuracy')

plt.figure()

# Plot training and validation loss per epoch
plt.plot(epochs, loss)
plt.plot(epochs, val_loss)
plt.title('Training and validation loss')
# Out:
# Text(0.5, 1.0, 'Training and validation loss')
